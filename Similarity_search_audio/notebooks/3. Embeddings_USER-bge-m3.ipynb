# %% [markdown]
# ## TODO
# * check for last short text part

# %%
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoModel
from datasets import load_dataset
from tqdm import tqdm
import random
from huggingface_hub import login
import pandas as pd
import numpy as np
import json
import gc
import os
import re

# %% [markdown]
# ---

# %% [markdown]
# # Openai embeddings

# %%
import openai

# %%
with open(r"D:/Programming/My_reps/OpenAI_for_MM_telegramm.txt", 'r') as f:
    openai_key = f.readlines()[0]
client = openai.OpenAI(api_key=openai_key)

def get_embedding(text, model='text-embedding-3-small'):
    if isinstance(text, str):
        text = [text]
    out = client.embeddings.create(input = text, model=model)
    return [o.embedding for o in out.data]

# %%
ds = pd.read_csv(r"D:\Programming\My_reps\MM_telegram_bot\tmp_dev\tmp\Тайны загробного мира. Талмуд по-русски. Рав Йосеф Менделевич #09-10-2024# [PQBXwFdsIIE].csv")

# %%
ds[ds['text'].notna()].reset_index(drop=True)
# Out:
#      start      end                                               text
# 0  3960.36  3994.12  но не все время будем учить Гимаре про мертвых...

# %%
vector = get_embedding('cypher language')
np.array(vector).shape
# Out:
# (1, 1536)

# %%
# generate embeddings
folder = r"D:\Programming\My_reps\Similarity_search_audio\tmp_work_files\texts_from_audio"
output_folder = r"D:\Programming\My_reps\Similarity_search_audio\tmp_work_files\embeddings_for_texts_openai"

# %%
with open(os.path.join(folder, 'processed_files.txt'), 'r') as f:
    processed_files = [p.replace('\n', '') for p in f.readlines()]
    
def update_processed(filename):
    global processed_files
    processed_files.append(filename)
    with open(os.path.join(folder, 'processed_files.txt'), 'a') as f:
        f.writelines(processed_files[-1] + '\n')

len(processed_files)
# Out:
# 59

# %%
ds[ds['text'].notna()]
# Out:
#       start      end                                               text
# 1      0.00   226.84  Миша Субтитры создавал DimaTorzok Песня на ара...
# 2    226.84   349.72  иран называлась персия и там разрешили царь ра...
# 3    349.72   460.04  повысить всех сыновей аммар и получили по всем...
# 4    460.04   599.44  Согласен. Но еще не до конца, мы могли освобод...
# 5    599.44   711.40  Ты вообще не свободный человек получается. Поэ...
# 6    711.40   837.00  нет 300 занят и не очень жениться пока нет еще...
# 7    837.00   949.90  Нет, то есть, что, когда они вырастут, это уже...
# 8    949.90  1068.00  Ну, а где ребята будут играть в футбол на стад...
# 9   1068.00  1193.00  Церковь, что есть у него, у него есть дом, что...
# 10  1193.00  1312.36  Вот, ты учил, ты уже готов себя быть женатым. ...
# 11  1312.36  1439.00  пока ты это строить это ты пока пока это на тр...
# 12  1439.00  1550.62  Вот это мечта, и ты спрашиваешь, это я мечтаю,...
# 13  1550.62  1629.98  и к этому придем значит потихонечку надо значи...

# %%
files = tqdm([o for o in os.listdir(folder) if o.endswith('csv')])
for filename in files:
    files.set_description(filename[:40])
    youtube_link = re.search(r"(\[[^\]]+\]).csv$", filename).group(1)
    if youtube_link in processed_files:
        continue
        
    file_path = os.path.join(folder, filename)
    ds = pd.read_csv(file_path)
    ds = ds[ds['text'].notna()]
    ds.to_csv(file_path, index=False)
    
    texts = ds.loc[:, 'text'].tolist()
    # summs = ds.loc[:, 'summarization'].tolist()

    embeddings_texts = get_embedding(texts)

    np.save(os.path.join(output_folder, os.path.splitext(filename)[0] + '.text.npy'), embeddings_texts)
    # np.save(os.path.join(output_folder, os.path.splitext(filename)[0] + '.summarization.npy'), embeddings_texts)

    update_processed(youtube_link)
# Out:
# בבתי כלא סובייטים אני  יוסף מנדלביץ #22-: 100%|██████████████████████████████████████| 847/847 [10:33<00:00,  1.34it/s]

# %%
texts

# %%
# !start .

# %%
filename
# Out:
# 'בבתי כלא סובייטים אני  יוסף מנדלביץ #22-08-2024# [tB-ZFRJQoJ4].csv'

# %% [markdown]
# ---

# %% [markdown]
# # Test

# %%
with open('D:\Programming\My_reps\Hugging_face_token_my.txt', 'r') as f:
    hf_token = f.readlines()[0]
login(hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to C:\Users\Otniel\.cache\huggingface\token
# Login successful

# %%
def average_pool(last_hidden_states: torch.Tensor,
                 attention_mask: torch.Tensor) -> torch.Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

def get_detailed_instruct(task_description: str, query: str) -> str:
    return f'Instruct: {task_description}\nQuery: {query}'

# %%
tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-large-instruct')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-large-instruct', torch_dtype=torch.bfloat16, trust_remote_code=True, 
                                  device_map="cuda").eval()

# %%
vector_base = []

dss = []
folder = r"D:\Programming\My_experiments\Audio\texts_from_audio"
embd_folder = r"D:\Programming\My_experiments\Audio\embeddings_for_texts_openai"

for filename in tqdm([o for o in os.listdir(folder) if o.endswith('csv')]):
    file_path = os.path.join(folder, filename)
    dss.append(pd.read_csv(file_path))
    dss[-1]['filename'] = filename
    embd_file_name = os.path.join(embd_folder, os.path.splitext(filename)[0] + ".text.npy")
    vector_base.append(torch.tensor(np.load(embd_file_name)))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 160.66it/s]

# %%
dss[0]
# Out:
#       start      end                                               text  \
# 0      0.00   115.36  Доброе утро. Я хотел повторить сперва, прежде ...
# 1    115.36   209.88  но то что есть мы понимаем мы царь на все я на...
# 2    209.88   335.90  Но надо проверить, с какого языка это взято, в...
# 3    335.90   478.84  входило в контекст теперь мы читаем повторение...
# 4    478.84   590.62  случае это не то и не сел а это как раз пробел...
# 5    590.62   713.38  и вы ему на м этого ему на да и потом будет ещ...
# 6    713.38   834.60  И оно, естественно, будет позволено, вставлени...
# 7    834.60   920.10  бы аллаха гуманной говорит это как бы не когда...
# 8    920.10  1077.00  Вот давайте сравним эти две, как бы сравним мн...
# 9   1077.00  1190.68  И дальше мы разбираем следующее. Теперь, «бепр...
# 10  1190.68  1302.34  это мы напомнили и поэтому мы возвращаемся на ...
# 11  1302.34  1416.74  То есть, мы знаем, окей, Мешив, Шоэ, Бепраким,...
# 12  1416.74  1503.20  какой причине он может и конечно мы предполага...
# 13  1503.20  1677.34  Агады это означает «сейчас». А вот в тексте о ...
# 14  1677.34  1795.62  Это Раби Юда, правильно? И после него его нет....
# 15  1795.62  1919.82  да и теперь когда мне как-то спрашиваете я хот...
# 16  1919.82  2027.44  могу по словам рабби мейера инициировать беним...
# 17  2027.44  2137.24  скажем о концовке. На самом деле, Эйма Сейфа д...
# 18  2137.24  2289.62  то, понятно, в пассивном состоянии мне, как ми...
# 19  2289.62  2396.12  Поэтому говорят, что евреи, ребята, которые уч...
# 20  2396.12  2518.02  Надо помнить, что сказали на предыдущей страни...
# 21  2518.02  2634.22  Мы не можем сказать, они оба правы, и они гово...
# 22  2634.22  2757.58  значит наше предположение было неправильное зн...
# 23  2757.58  2878.58  текст эту мишну надо дописать не будем перевод...
# 24  2878.58  2992.46  Нет необходимости, это то же самое. Понятно? Т...
# 25  2992.46  3115.72  Потому что люди до этого думали, что разрешени...
# 26  3115.72  3238.56  это так начинаешь думать логично все не так во...
# 27  3238.56  3357.88  У него на том же самом уровне. Можно иницииров...
# 28  3357.88  3475.36  запоминание текста без особого углубления и ан...
# 29  3475.36  3598.42  гемора есть такая на самом деле брайка то что ...
# 30  3598.42  3720.70  это в какой-то степени случайно, неожиданно, д...
# 31  3720.70  3840.00  Ахи Тана. У меня написано Ахай. Разное. Сейчас...
# 32  3840.00  3956.32  Да, на самом деле «могу» – это ведь на самом д...
# 33  3956.32  4059.00  О дильма, или же возможно, дильма это возможно...
# 34  4059.00  4190.34  Нет, пусек может прерваться, это нормально. Эй...
# 35  4190.34  4229.54  разве неужели слова и не это тоже стоит внести...
#
#                                              filename
# 0   В жизни логика не работает. Урок №4. Талмуд по...
# 1   В жизни логика не работает. Урок №4. Талмуд по...
# 2   В жизни логика не работает. Урок №4. Талмуд по...
# 3   В жизни логика не работает. Урок №4. Талмуд по...
# 4   В жизни логика не работает. Урок №4. Талмуд по...
# 5   В жизни логика не работает. Урок №4. Талмуд по...
# 6   В жизни логика не работает. Урок №4. Талмуд по...
# 7   В жизни логика не работает. Урок №4. Талмуд по...
# 8   В жизни логика не работает. Урок №4. Талмуд по...
# 9   В жизни логика не работает. Урок №4. Талмуд по...
# 10  В жизни логика не работает. Урок №4. Талмуд по...
# 11  В жизни логика не работает. Урок №4. Талмуд по...
# 12  В жизни логика не работает. Урок №4. Талмуд по...
# 13  В жизни логика не работает. Урок №4. Талмуд по...
# 14  В жизни логика не работает. Урок №4. Талмуд по...
# 15  В жизни логика не работает. Урок №4. Талмуд по...
# 16  В жизни логика не работает. Урок №4. Талмуд по...
# 17  В жизни логика не работает. Урок №4. Талмуд по...
# 18  В жизни логика не работает. Урок №4. Талмуд по...
# 19  В жизни логика не работает. Урок №4. Талмуд по...
# 20  В жизни логика не работает. Урок №4. Талмуд по...
# 21  В жизни логика не работает. Урок №4. Талмуд по...
# 22  В жизни логика не работает. Урок №4. Талмуд по...
# 23  В жизни логика не работает. Урок №4. Талмуд по...
# 24  В жизни логика не работает. Урок №4. Талмуд по...
# 25  В жизни логика не работает. Урок №4. Талмуд по...
# 26  В жизни логика не работает. Урок №4. Талмуд по...
# 27  В жизни логика не работает. Урок №4. Талмуд по...
# 28  В жизни логика не работает. Урок №4. Талмуд по...
# 29  В жизни логика не работает. Урок №4. Талмуд по...
# 30  В жизни логика не работает. Урок №4. Талмуд по...
# 31  В жизни логика не работает. Урок №4. Талмуд по...
# 32  В жизни логика не работает. Урок №4. Талмуд по...
# 33  В жизни логика не работает. Урок №4. Талмуд по...
# 34  В жизни логика не работает. Урок №4. Талмуд по...
# 35  В жизни логика не работает. Урок №4. Талмуд по...

# %%
vector_base[0].shape
# Out:
# torch.Size([36, 1536])

# %%
# query = ['как учить талмуд']
query = ['капля молока попала в мясной суп, что делать?']

# %% [raw]
# # local
# with torch.no_grad():
#     encoded_input = tokenizer(query, padding=True, truncation=True, return_tensors='pt')
#     outputs = model(**encoded_input.to('cuda'))
#     query_embeddings = outputs[0][:, 0].to('cpu')
#     query_embeddings = torch.nn.functional.normalize(query_embeddings, p=2, dim=1).to(torch.float16)
#
#     torch.cuda.empty_cache()
#     gc.collect()
#
# results = []
# for i, vect in enumerate(vector_base):
#     scores = (query_embeddings.to(torch.float32) @ vect.to(torch.float32).T) * 100
#     results.extend([[score, i, j] for j, score in enumerate(scores.numpy()[0])])

# %%
# Openai|
query_embeddings = get_embedding(query)

# %%
results = []
for i, vect in enumerate(vector_base):
    scores = (torch.tensor(query_embeddings) @ vect.to(torch.float32).T) * 100
    results.extend([[score, i, j] for j, score in enumerate(scores.numpy()[0])])

# %%
results

# %%
sorted(results, key=lambda x:-x[0])

# %%
for res in sorted(results, key=lambda x:-x[0])[:5]:
    print(res, dss[res[1]].loc[res[2], 'filename'], '\n', dss[res[1]].loc[res[2], 'text'], '\n')
# Out:
# [36.019146, 42, 10] Рав Элиягу Бережинский. Чуть - чуть про кашрут (7). Еврейское вино. [VRZzTTDbls4].csv
#  абсолютно значит единственное что здесь нужно чтобы пропорция была довольно большая то есть изюмом и добавляем не горстку на кастрюлю а нужно на кастрюлю 6 литровую кастрюлю килограмм с хвостиком или килограмм изюмой чуть-чуть не долить кастрюлю сварил компот у тебя есть сейчас там 5 литров или 4,5 литра вина для Песаха. Тебе не хватит? Хватит. Можно пить даже компоты, он тоже будет буре при Агафе. Такой компот, если у тебя есть время, и ты это делаешь заранее, сделать это за месяц, потому что пока оно забродит, это где-то недели 3-4 берет. На месяц ты можешь сделать вино из изюма, а можешь сделать ускоренный вариант. Взял изюм, сварил его, дал ему остыть и выпил вечером остывший компот, который ты в этот день сделал. Можно подождать, пока компот забродит. Такой вариант, в принципе, тоже может быть, но это сложный вариант, потому что после полноценной варки, как мы уже сказали, брожения нормального не будет. То есть после этого ты должен добавить снова-таки живой виноград, или живой изюм, чтобы начался процесс брожения.
#
# [35.382084, 42, 19] Рав Элиягу Бережинский. Чуть - чуть про кашрут (7). Еврейское вино. [VRZzTTDbls4].csv
#  проблемы что в принципе но здесь есть вопрос насколько он сильный если уксус сделан из винный уксус сделан из не еврейского вина то он по определению будет запрещен поэтому все те кто говорят а если я пойду в какой-то там супер веганский ресторан там же будет все кошерность что-то может быть не кошерного перечислить перечислить имя что-то может быть не кошер какие какие я спросил что такое веган знаешь не мясо не не молоко, ни рыба, ни яйца. Прежде всего там могут быть спокойно насекомые. Там может быть винный уксус. Там может быть нееврейская варка. Там много чего может быть. Гарантии, что там все кошерное никакой нету то что ты убрал мясо молоко и рыбу часть проблем ты убрал а часть у тебя осталось как и были а и даже салатик не поешь, потому что в этот салатик очень легко могли положить винный уксус. Или положили каширный, который резали. Нет? Что именно резали не каширного? Не знаю, кто это? В веганском ресторане.
#
# [32.754852, 42, 23] Рав Элиягу Бережинский. Чуть - чуть про кашрут (7). Еврейское вино. [VRZzTTDbls4].csv
#  Почему он не испортил? С точки зрения его намерения. Что он сейчас двигал? Воду. Он двигал воду. Там было вино, но он двигал воду. Это его намерение. Он сейчас это поставил, ничего не запретилось. есть еще отдельно давай может быть посмотрим Секундочку. Секундочку. Если Влайку пришел к Илише домой, и у него есть в холодильнике сейчас открытое вино. В лайку нельзя его прикасаться, но мы не говорим, а вдруг, пока он там был, он прикоснулся. То есть, если есть нееврей, который помогает, то мы не будем опасаться, если мы не видим непосредственно, что он взял, что он прикасался к этому вину, его запретил. Если обычно там нееврея нет, это хороший вопрос. Неев еврей пришел пошастал по дому самый классический пример к сожалению слышал очень много таких примеров когда приезжают нееврейские родственники к нашим выпускникам ой я получаю сразу кучу звонков а что мне делать а он взял это он взял это он сейчас в молочной сковородке приготовила он сейчас ой-ой-ой мясо с молоком рыба шмиба все пропало шеф если такой родственник появился то то, извините, открытое вино. Goodbye. А у меня вопрос. Да. Есть ли еврей, который не хранит емшиба, затронутся до вина, он считается... Нет.
#
# [32.5247, 2, 3] Рав Авраам Адлер. Недельная глава Беаалотха. [4Bkk1fMAMOA].csv
#  если можно можно сказать что-то просят все я понимаю дать или пошліть якусь делегацію з кимось, може, один, двоє, ні, вже, у-у-у. Ну, так вони на Моше, давлять на Моше. Моше, може, ми піднімемося трохи вище. Трохи вище навіть піднімемося. Благослови меня, Господи, что ты делаешь так мне тяжело, почему все на меня взволнилось. И почему? Потому что они не хотят, чтобы они не могли принять массаж. Все на моих плечах, все есть единственное. Но когда я увидел, что этот народ родился, и когда я увидел, что они берут его, как будто берешь младенца по той или иной причине, что тогда этот народ будет носить, носить, носить, не знаю. Потому что это жалоба, потому что это тяж тяжело можно тоже понять давит давит мая либо сан по сути нас откуда меня столько мясо для такого мы здесь говорим про миллион людей миллиона может 23 миллиона людей если откуда прям такую сумму если 600 тысяч взрослого поколения только мужчина то же самое параллельно женщин взрослого покоління, тільки чоловіків, так само і паралельно з жінками, взрослі – понад 60 років, менші – 20 років. Виходить, що ці дві спільноти можуть навіть три мільйони. Кормити таку масу, куди є стільки м'яса. Але, мабуть, в Києві, в Києві, в Львіві, в морі, треба вбазати, бо вони не плачуть, дай нам м'ясо. А я не не могу сам. И показывает, лучше умерти меня, чем я не могу. Говорит, ну это не в твоих силах.
#
# [31.996082, 42, 18] Рав Элиягу Бережинский. Чуть - чуть про кашрут (7). Еврейское вино. [VRZzTTDbls4].csv
#  Но так как у него было намерение, то раб сказал мусорку. Кто же будет с хозяином спорить тем более когда это главный раввин израиля нет категорически нет категорически нет он сказал он сказал нет без всякой шутки когда я говорю когда у меня попробовали то я так и сделал я спокойно отдал с точки зрения логической нет проблемы дать но здесь человек хотел это сделать давать ему за это награду нельзя не с точки зрения того что жалко или из-за того что она не кошерно отдать награду человеку который специально стремится испортить насчет малины не знаю надо будет сходить покушать, говорят, у нас на перекрестке начали плодоносить малины. Привозите. А? В смысле привозите? Это платное удовольствие. Привозите. Вино, которое замерзло в лед. И к нему прикоснулся не еврей замерзшему вину к ледышке он его не испортил если мы говорим про уксус если это сильный уксус и он сделан из кошерного вина то у меня нет

# %% [markdown]
# # Example Gemma2

# %%
# Each query must come with a one-sentence instruction that describes the task
task = 'Given a web search query, retrieve relevant passages that answer the query'
queries = [
    get_detailed_instruct(task, 'how much protein should a female eat'),
    get_detailed_instruct(task, 'big objects in space like quasars'),
    get_detailed_instruct(task, 'большие объекты в космосе такие как квазары'),
    get_detailed_instruct(task, '南瓜的家常做法')
]
# No need to add instruction for retrieval documents
documents = [
    "As a general guideline, the CDC's average requirement of protein for women ages 19 to 70 is 46 grams per day. But, as you can see from this chart, you'll need to increase that if you're expecting or training for a marathon. Check out the chart below to see how much protein you should be eating each day.",
    "1.清炒南瓜丝 原料:嫩南瓜半个 调料:葱、盐、白糖、鸡精 做法: 1、南瓜用刀薄薄的削去表面一层皮,用勺子刮去瓤 2、擦成细丝(没有擦菜板就用刀慢慢切成细丝) 3、锅烧热放油,入葱花煸出香味 4、入南瓜丝快速翻炒一分钟左右,放盐、一点白糖和鸡精调味出锅 2.香葱炒南瓜 原料:南瓜1只 调料:香葱、蒜末、橄榄油、盐 做法: 1、将南瓜去皮,切成片 2、油锅8成热后,将蒜末放入爆香 3、爆香后,将南瓜片放入,翻炒 4、在翻炒的同时,可以不时地往锅里加水,但不要太多 5、放入盐,炒匀 6、南瓜差不多软和绵了之后,就可以关火 7、撒入香葱,即可出锅"
]
input_texts = queries + documents

# %%
# Tokenize the input texts
with torch.no_grad():
    batch_dict = tokenizer(input_texts, max_length=512, padding=True, truncation=True, return_tensors='pt')
    outputs = model(**batch_dict.to('cuda'))
    embeddings = average_pool(outputs.last_hidden_state.cpu(), batch_dict['attention_mask'].cpu())
    torch.cuda.empty_cache()
    gc.collect()

# %%
# normalize embeddings
embeddings = F.normalize(embeddings, p=2, dim=1)
scores = (embeddings[:4] @ embeddings[4:].T) * 100
print(scores.tolist())
# Out:
# [[92.0, 67.5], [70.5, 63.0], [68.0, 64.5], [70.5, 92.5]]

# %% [markdown]
# # Example USER-bge-m3

# %%
tokenizer = AutoTokenizer.from_pretrained("deepvk/USER-bge-m3")
model = AutoModel.from_pretrained("deepvk/USER-bge-m3", torch_dtype=torch.bfloat16, trust_remote_code=True, 
                                  device_map="cuda").eval()

# %%
input_texts = [
  "Когда был спущен на воду первый миноносец «Спокойный»?",
  "Есть ли нефть в Удмуртии?",
  'большие объекты в космосе такие как квазары',
  "Спокойный (эсминец)\nЗачислен в списки ВМФ СССР 19 августа 1952 года.",
  "Нефтепоисковые работы в Удмуртии были начаты сразу после Второй мировой войны в 1945 году и продолжаются по сей день. Добыча нефти началась в 1967 году."
]

# %%
with torch.no_grad():
    encoded_input = tokenizer(input_texts, padding=True, truncation=True, return_tensors='pt')
    outputs = model(**encoded_input.to('cuda'))
    sentence_embeddings = outputs[0][:, 0].to('cpu')
    torch.cuda.empty_cache()
    gc.collect()

# %%
# normalize embeddings
sentence_embeddings = torch.nn.functional.normalize(sentence_embeddings, p=2, dim=1)
scores = (sentence_embeddings[:3] @ sentence_embeddings[3:].T)
scores
# Out:
# tensor([[0.5547, 0.3027],
#         [0.1689, 0.7109],
#         [0.1406, 0.1885]], dtype=torch.bfloat16)

# %% [markdown]
# # Generate embeddings

# %%
# generate embeddings
folder = r"D:\Programming\My_experiments\Audio\texts_from_audio"
output_folder = r"D:\Programming\My_experiments\Audio\embeddings_for_texts"

for filename in tqdm(os.listdir(folder)):
    file_path = os.path.join(folder, filename)
    ds = pd.read_csv(file_path)
    texts = ds.loc[:, 'text'].tolist()
    summs = ds.loc[:, 'summarization'].tolist()

    with torch.no_grad():
        encoded_input = tokenizer(texts, padding=True, truncation=True, return_tensors='pt')
        outputs = model(**encoded_input.to('cuda'))
        embeddings_texts = outputs[0][:, 0].to('cpu')
        embeddings_texts = torch.nn.functional.normalize(embeddings_texts, p=2, dim=1).to(torch.float16).numpy()

        encoded_input = tokenizer(summs, padding=True, truncation=True, return_tensors='pt')
        outputs = model(**encoded_input.to('cuda'))
        embeddings_summs = outputs[0][:, 0].to('cpu')
        embeddings_summs = torch.nn.functional.normalize(embeddings_summs, p=2, dim=1).to(torch.float16).numpy()
        
        torch.cuda.empty_cache()
        gc.collect()

    np.save(os.path.join(output_folder, os.path.splitext(filename)[0] + '.text.npy'), embeddings_texts)
    np.save(os.path.join(output_folder, os.path.splitext(filename)[0] + '.summarization.npy'), embeddings_texts)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:20<00:00,  2.46it/s]
